# %%
from nba_api.stats.static import teams, players
from nba_api.stats.endpoints import (cumestatsteamgames, 
                                    cumestatsteam, 
                                    gamerotation, 
                                    teamgamelogs, 
                                    playergamelogs,
                                    draftboard)
import pandas as pd
import numpy as np
import json
import difflib
import time
import requests
from IPython.display import display

# %%
def retry(func, retries=3):
    def retry_wrapper(*args, **kwargs):
        attempts = 0
        while attempts < retries:
            try:
                return func(*args, **kwargs)
            except (requests.exceptions.RequestException, json.JSONDecodeError) as e:
                print(f"Attempt {attempts + 1} failed: {e}")
                time.sleep(30)
                attempts += 1
        raise Exception(f"Failed after {retries} attempts")
    return retry_wrapper

# %%
# =============================================================================
# ULTRA-FAST: TeamGameLogs (plural) - ALL teams in ONE API call per season!
# See: https://github.com/swar/nba_api/blob/master/docs/nba_api/stats/endpoints/teamgamelogs.md
# =============================================================================

def getTeamGameLogs(seasons, season_type='Regular Season'):
    """
    Get all team game logs using TeamGameLogs endpoint.
    ONE API call per season gets ALL 30 teams' data
    
    Args:
        seasons: List of season years (e.g., [2022, 2023] for 2022-23 and 2023-24)
        season_type: 'Regular Season', 'Playoffs', etc.
    
    Returns:
        DataFrame with all team game logs
    """
    
    @retry
    def fetch_all_team_logs(season_str, season_type):
        """Fetch ALL teams' game logs in ONE call!"""
        logs = teamgamelogs.TeamGameLogs(
            season_nullable=season_str,
            season_type_nullable=season_type
        )
        return logs.get_data_frames()[0]
    
    all_logs = []
    
    for season in seasons:
        season_str = f"{season}-{str(season + 1)[-2:]}"
        print(f"Loading Team Game Logs for {season_str} {season_type}...", end=" ")
        
        time.sleep(0.6)  # Rate limiting
        
        try:
            df = fetch_all_team_logs(season_str, season_type)
            all_logs.append(df)
            print(f"✓ {len(df)} records")
        except Exception as e:
            print(f"ERROR: {e}")
    
    # Combine all seasons
    game_logs = pd.concat(all_logs, ignore_index=True)
    
    # Parse game date
    game_logs['GAME_DATE'] = pd.to_datetime(game_logs['GAME_DATE'])
    
    # Add W column (1 for win, 0 for loss)
    game_logs['W'] = (game_logs['WL'] == 'W').astype(int)
    
    # Determine home/away from MATCHUP column
    game_logs['IS_HOME'] = game_logs['MATCHUP'].str.contains('vs.').astype(int)
    
    print(f"\n✓ Loaded {len(game_logs)} total game records")
    print(f"  Unique games: {game_logs['GAME_ID'].nunique()}")
    print(f"  Teams: {game_logs['TEAM_ID'].nunique()}")
    
    return game_logs


def getPlayerGameLogs(seasons, season_type='Regular Season'):
    """
    Get all team game logs using TeamGameLogs endpoint.
    ONE API call per season gets ALL 30 teams' data
    
    Args:
        seasons: List of season years (e.g., [2022, 2023] for 2022-23 and 2023-24)
        season_type: 'Regular Season', 'Playoffs', etc.
    
    Returns:
        DataFrame with all team game logs
    """
    
    @retry
    def fetch_all_team_logs(season_str, season_type):
        """Fetch ALL teams' game logs in ONE call!"""
        logs = playergamelogs.PlayerGameLogs(
            season_nullable=season_str,
            season_type_nullable=season_type
        )
        return logs.get_data_frames()[0]
    

    all_logs = []
    
    for season in seasons:
        season_str = f"{season}-{str(season + 1)[-2:]}"
        print(f"Loading Player Game Logs for {season_str} {season_type}...", end=" ")
        
        time.sleep(0.6)  # Rate limiting
        
        try:
            df = fetch_all_team_logs(season_str, season_type)
            all_logs.append(df)
            print(f"✓ {len(df)} records")
        except Exception as e:
            print(f"ERROR: {e}")
    
    # Combine all seasons
    game_logs = pd.concat(all_logs, ignore_index=True)
    
    # Parse game date
    game_logs['GAME_DATE'] = pd.to_datetime(game_logs['GAME_DATE'])
    
    # Add W column (1 for win, 0 for loss)
    game_logs['W'] = (game_logs['WL'] == 'W').astype(int)
    
    # Determine home/away from MATCHUP column
    game_logs['IS_HOME'] = game_logs['MATCHUP'].str.contains('vs.').astype(int)
    
    print(f"\n✓ Loaded {len(game_logs)} total game records")
    print(f"  Unique games: {game_logs['GAME_ID'].nunique()}")
    print(f"  Teams: {game_logs['TEAM_ID'].nunique()}")
    
    return game_logs


def getPlayerDraftData(seasons):
    @retry
    def fetch_all_draft_data(season_str):
        """Fetch ALL teams' game logs in ONE call!"""
        logs = draftboard.DraftBoard(
            season_year=season_str,
        )
        return logs.get_data_frames()[0]
    

    all_logs = []
    
    for season in seasons:
        season_str = f"{season}-{str(season + 1)[-2:]}"
        print(f"Loading Player Draft Data for {season_str} ...", end=" ")
        
        time.sleep(0.6)  # Rate limiting
        
        try:
            df = fetch_all_draft_data(season)
            all_logs.append(df)
            print(f"✓ {len(df)} records")
        except Exception as e:
            print(f"ERROR: {e}")
    
    # Combine all seasons
    draft_data = pd.concat(all_logs, ignore_index=True)
    
    # Parse game date
    # game_logs['GAME_DATE'] = pd.to_datetime(game_logs['GAME_DATE'])
    
    # # Add W column (1 for win, 0 for loss)
    # game_logs['W'] = (game_logs['WL'] == 'W').astype(int)
    
    # # Determine home/away from MATCHUP column
    # game_logs['IS_HOME'] = game_logs['MATCHUP'].str.contains('vs.').astype(int)
    
    print(f"\n✓ Loaded {len(draft_data)} total game records")
    print(f"  Unique Players: {draft_data['PERSON_ID'].nunique()}")
    print(f"  Teams: {draft_data['TEAM_ID'].nunique()}")
    
    return draft_data


def addFeaturesToGameLogs(game_logs):
    """
    Add derived features to game logs (rolling averages, win %, etc.)
    Works with data from getGameLogsBulk()
    """
    df = game_logs.copy()
    
    # Sort by team and date for proper rolling calculations
    df = df.sort_values(['TEAM_ID', 'SEASON', 'GAME_DATE']).reset_index(drop=True)
    
    # Calculate Offensive Efficiency: (FGM + AST) / (FGA - OREB + AST + TOV)
    df['OFFENSIVE_EFFICIENCY'] = (df['FGM'] + df['AST']) / (df['FGA'] - df['OREB'] + df['AST'] + df['TOV'])
    
    # Calculate Scoring Margin (need opponent score - will compute after merging home/away)
    # For now, we can use PLUS_MINUS as a proxy
    df['SCORING_MARGIN'] = df['PLUS_MINUS']
    
    # Rolling averages (last 3 games)
    df['ROLLING_OE'] = df.groupby(['TEAM_ID', 'SEASON'])['OFFENSIVE_EFFICIENCY'].transform(
        lambda x: x.rolling(3, min_periods=1).mean()
    )
    df['ROLLING_SCORING_MARGIN'] = df.groupby(['TEAM_ID', 'SEASON'])['SCORING_MARGIN'].transform(
        lambda x: x.rolling(3, min_periods=1).mean()
    )
    
    # Cumulative win percentage
    df['GAMES_PLAYED'] = df.groupby(['TEAM_ID', 'SEASON']).cumcount() + 1
    df['TOTAL_WINS'] = df.groupby(['TEAM_ID', 'SEASON'])['W'].cumsum()
    df['TOTAL_WIN_PCTG'] = df['TOTAL_WINS'] / df['GAMES_PLAYED']
    
    # Home/Away win percentages
    df['HOME_GAMES'] = df.groupby(['TEAM_ID', 'SEASON'])['IS_HOME'].cumsum()
    df['HOME_WINS'] = df.groupby(['TEAM_ID', 'SEASON']).apply(
        lambda x: (x['W'] * x['IS_HOME']).cumsum()
    ).reset_index(level=0, drop=True)
    df['HOME_WIN_PCTG'] = df['HOME_WINS'] / df['HOME_GAMES'].replace(0, np.nan)
    
    df['AWAY_GAMES'] = df['GAMES_PLAYED'] - df['HOME_GAMES']
    df['AWAY_WINS'] = df['TOTAL_WINS'] - df['HOME_WINS']
    df['AWAY_WIN_PCTG'] = df['AWAY_WINS'] / df['AWAY_GAMES'].replace(0, np.nan)
    
    # Rest days
    df['LAST_GAME_DATE'] = df.groupby(['TEAM_ID', 'SEASON'])['GAME_DATE'].shift(1)
    df['NUM_REST_DAYS'] = (df['GAME_DATE'] - df['LAST_GAME_DATE']).dt.days
    
    # Clean up intermediate columns
    df = df.drop(['GAMES_PLAYED', 'TOTAL_WINS', 'HOME_GAMES', 'HOME_WINS', 
                  'AWAY_GAMES', 'AWAY_WINS', 'LAST_GAME_DATE'], axis=1)
    
    return df

# %%
seasons_to_load = [2025]

team_game_logs = getTeamGameLogs(seasons_to_load, season_type='Regular Season')
player_game_logs = getPlayerGameLogs(seasons_to_load, season_type='Regular Season')
# draft_data = getPlayerDraftData(seasons_to_load)


display(team_game_logs.head())
display(player_game_logs.head())
# display(draft_data.head())
# Out:
# Loading Team Game Logs for 2025-26 Regular Season... ✓ 1394 records
#
# ✓ Loaded 1394 total game records
#   Unique games: 697
#   Teams: 30
# Loading Player Game Logs for 2025-26 Regular Season... ✓ 15137 records
#
# ✓ Loaded 15137 total game records
#   Unique games: 697
#   Teams: 30
#   SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0     2025-26  1610612755               PHI     Philadelphia 76ers
# 1     2025-26  1610612752               NYK        New York Knicks
# 2     2025-26  1610612746               LAC            LA Clippers
# 3     2025-26  1610612760               OKC  Oklahoma City Thunder
# 4     2025-26  1610612764               WAS     Washington Wizards
#
#       GAME_ID  GAME_DATE      MATCHUP WL   MIN  FGM  ...  STL_RANK  BLK_RANK  \
# 0  0022500666 2026-01-27  PHI vs. MIL  W  48.0   53  ...       816       513
# 1  0022500665 2026-01-27  NYK vs. SAC  W  48.0   37  ...       228      1309
# 2  0022500670 2026-01-27    LAC @ UTA  W  48.0   41  ...       324       980
# 3  0022500667 2026-01-27  OKC vs. NOP  W  48.0   35  ...      1267        59
# 4  0022500664 2026-01-27  WAS vs. POR  W  48.0   40  ...        14         5
#
#    BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  AVAILABLE_FLAG  W  \
# 0        416      866      1350        46              166               1  1
# 1        226      186      1129      1152              192               1  1
# 2        226      481      1022       688              288               1  1
# 3       1370      110       530      1126              370               1  1
# 4        664      267      1022       688              539               1  1
#
#    IS_HOME
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#
# [5 rows x 59 columns]
#   SEASON_YEAR  PLAYER_ID         PLAYER_NAME NICKNAME     TEAM_ID  \
# 0     2025-26    1642259           Alex Sarr     Alex  1610612764
# 1     2025-26    1629008  Michael Porter Jr.  Michael  1610612751
# 2     2025-26     202331         Paul George     Paul  1610612755
# 3     2025-26    1631096       Chet Holmgren     Chet  1610612760
# 4     2025-26    1626167        Myles Turner    Myles  1610612749
#
#   TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  GAME_DATE  \
# 0               WAS     Washington Wizards  0022500664 2026-01-27
# 1               BKN          Brooklyn Nets  0022500669 2026-01-27
# 2               PHI     Philadelphia 76ers  0022500666 2026-01-27
# 3               OKC  Oklahoma City Thunder  0022500667 2026-01-27
# 4               MIL        Milwaukee Bucks  0022500666 2026-01-27
#
#        MATCHUP  ... PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  \
# 0  WAS vs. POR  ...            1249                    42         1        72
# 1    BKN @ PHX  ...            7050                   449      1104        72
# 2  PHI vs. MIL  ...            1845                   576      1104        72
# 3  OKC vs. NOP  ...            4835                   317         1        72
# 4    MIL @ PHI  ...           10522                   859      1104        72
#
#    WNBA_FANTASY_PTS_RANK  AVAILABLE_FLAG  MIN_SEC  TEAM_COUNT  W  IS_HOME
# 0                     72               1    36:07           1  1        1
# 1                    218               1    36:59           1  0        0
# 2                    255               1    32:58           1  1        1
# 3                    641               1    32:59           1  1        1
# 4                    641               1    35:27           1  0        0
#
# [5 rows x 72 columns]

# %%
player_game_logs[player_game_logs["PLAYER_NAME"] == "Cooper Flagg"]
# Out:
#       SEASON_YEAR  PLAYER_ID   PLAYER_NAME NICKNAME     TEAM_ID  \
# 463       2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 746       2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 1232      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 2149      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 2351      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 2760      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 3030      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 3363      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 3868      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 4218      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 4607      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 4989      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 5366      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 5473      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 5812      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 6108      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 6399      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 6674      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 6998      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 7533      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 7782      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 8079      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 8393      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 8742      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 8938      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 9462      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 9829      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 9946      2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 10621     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 10725     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 11062     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 11258     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 11664     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 12042     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 12245     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 12462     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 12899     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 13227     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 13660     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 14124     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 14234     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 14555     2025-26    1642843  Cooper Flagg   Cooper  1610612742
# 14938     2025-26    1642843  Cooper Flagg   Cooper  1610612742
#
#       TEAM_ABBREVIATION         TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP  \
# 463                 DAL  Dallas Mavericks  0022500648 2026-01-24  DAL vs. LAL
# 746                 DAL  Dallas Mavericks  0022500630 2026-01-22  DAL vs. GSW
# 1232                DAL  Dallas Mavericks  0022500016 2026-01-19    DAL @ NYK
# 2149                DAL  Dallas Mavericks  0022500575 2026-01-14  DAL vs. DEN
# 2351                DAL  Dallas Mavericks  0022500561 2026-01-12  DAL vs. BKN
# 9946                     908               1    32:21           1  1        1
# 10621                   7036               1    26:51           1  0        0
# 10725                   1364               1    37:06           1  1        1
# 11062                   5914               1    47:39           1  0        1
# 11258                   1364               1    33:42           1  0        1
# 11664                    818               1    34:46           1  0        1
# 12042                   3904               1    33:43           1  1        0
# 12245                   5200               1    27:16           1  0        0
# 12462                   1243               1    35:02           1  0        1
# 12899                   5914               1    33:57           1  0        0
# 13227                   3073               1    33:30           1  0        0
# 13660                   3360               1    35:04           1  1        1
# 14124                  11719               1    31:08           1  0        1
# 14234                   2598               1    28:54           1  1        1
# 14555                   2373               1    34:39           1  0        1
# 14938                   6277               1    31:32           1  0        1
#
# [43 rows x 72 columns]

# %%
import requests
import pandas as pd

def getDraftBoardFromContentAPI(year):
    """
    Fetch draft board from NBA's Content API.
    Has birthday, height, weight, school, position, etc.
    """
    url = f"https://content-api-prod.nba.com/public/1/leagues/nba/draft/{year}/board"
    
    headers = {
        'User-Agent': 'Mozilla/5.0',
        'Accept': 'application/json'
    }
    
    response = requests.get(url, headers=headers)
    data = response.json()
    
    # Extract picks from first and second round
    picks = []
    
    for round_name in ['firstRound', 'secondRound']:
        round_picks = data['results']['picks'].get(round_name, [])
        for pick in round_picks:
            prospect = pick.get('prospect', {})
            team = pick.get('team', {})
            
            picks.append({
                'PICK_NUMBER': pick.get('pickNumber'),
                'PLAYER_NAME': prospect.get('displayName'),
                'FIRST_NAME': prospect.get('firstName'),
                'LAST_NAME': prospect.get('lastName'),
                'POSITION': prospect.get('position'),
                'HEIGHT': prospect.get('height', {}).get('feetAndInches'),
                'HEIGHT_INCHES': prospect.get('height', {}).get('inchesOnly'),
                'WEIGHT': prospect.get('weightLbs'),
                'SCHOOL': prospect.get('school'),
                'BIRTHDAY': prospect.get('birthday'),
                'COUNTRY': prospect.get('country'),
                'TEAM_ID': team.get('teamId'),
                'TEAM_NAME': team.get('teamName'),
                'TEAM_ABBR': team.get('teamAbbr'),
                'SEASON': year
            })
    
    return pd.DataFrame(picks)

# Usage:
draft_2025 = getDraftBoardFromContentAPI(2025)
draft_2025.head()
# Out:
# {'pickNumber': 1, 'pickDetails': '', 'team': {'id': 1748283, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612742, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '39-43', 'seasonFinish': '3rd place, Southwest Division', 'playoffsFinish': 'Lost in SoFi Play-In Tournament'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-dallas-mavericks', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-dallas-mavericks?hidenav=true', 'tradeDetails': [], 'teamName': 'Dallas Mavericks', 'teamAbbr': 'DAL', 'pickedFirstRound': True}, 'prospect': {'id': 1753201, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Cooper Flagg', 'firstName': 'Cooper', 'lastName': 'Flagg', 'permalink': 'https://www.nba.com/draft/2025/prospects/cooper-flagg', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/cooper-flagg?hidenav=true', 'position': 'F', 'height': {'feetAndInches': '6-8', 'inchesOnly': 80}, 'weightLbs': 221, 'school': 'Duke', 'status': 'Freshman', 'birthday': '12/21/2006', 'country': 'United States', 'tradeDetails': []}}
# {'pickNumber': 2, 'pickDetails': '', 'team': {'id': 1748318, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612759, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '34-48', 'seasonFinish': '4th place, Southwest Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-san-antonio-spurs', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-san-antonio-spurs?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Traded Kam Jones (No. 38) to IND', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'San Antonio Spurs', 'teamAbbr': 'SAS', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1753352, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Dylan Harper', 'firstName': 'Dylan', 'lastName': 'Harper', 'permalink': 'https://www.nba.com/draft/2025/prospects/dylan-harper', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/dylan-harper?hidenav=true', 'position': 'G', 'height': {'feetAndInches': '6-5', 'inchesOnly': 77}, 'weightLbs': 213, 'school': 'Rutgers', 'status': 'Freshman', 'birthday': '03/02/2006', 'country': 'United States', 'tradeDetails': []}}
# {'pickNumber': 3, 'pickDetails': '', 'team': {'id': 1748314, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612755, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '24-58', 'seasonFinish': '5th place, Atlantic Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-philadelphia-76ers', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-philadelphia-76ers?hidenav=true', 'tradeDetails': [], 'teamName': 'Philadelphia 76ers', 'teamAbbr': 'PHI', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1753617, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'VJ Edgecombe', 'firstName': 'VJ', 'lastName': 'Edgecombe', 'permalink': 'https://www.nba.com/draft/2025/prospects/vj-edgecombe', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/vj-edgecombe?hidenav=true', 'position': 'G', 'height': {'feetAndInches': '6-4', 'inchesOnly': 76}, 'weightLbs': 193, 'school': 'Baylor', 'status': 'Freshman', 'birthday': '07/30/2005', 'country': 'Bahamas', 'tradeDetails': []}}
# {'pickNumber': 4, 'pickDetails': '', 'team': {'id': 1748275, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612766, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '19-63', 'seasonFinish': '5th place, Southeast Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-charlotte-hornets', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-charlotte-hornets?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Acquired Liam McNeeley (No. 29) from PHX', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Charlotte Hornets', 'teamAbbr': 'CHA', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1753775, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Kon Knueppel', 'firstName': 'Kon', 'lastName': 'Knueppel', 'permalink': 'https://www.nba.com/draft/2025/prospects/kon-knueppel', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/kon-knueppel?hidenav=true', 'position': 'G-F', 'height': {'feetAndInches': '6-7', 'inchesOnly': 79}, 'weightLbs': 217, 'school': 'Duke', 'status': 'Freshman', 'birthday': '08/03/2005', 'country': 'United States', 'tradeDetails': []}}
# {'pickNumber': 5, 'pickDetails': '', 'team': {'id': 1748320, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612762, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '17-65', 'seasonFinish': '5th, Northwest Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-utah-jazz', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-utah-jazz?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Acquired Walter Clayton Jr. (No. 18) from WAS', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Traded Will Riley (No. 21) to WAS', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Utah Jazz', 'teamAbbr': 'UTA', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1753378, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Ace Bailey', 'firstName': 'Ace', 'lastName': 'Bailey', 'permalink': 'https://www.nba.com/draft/2025/prospects/ace-bailey', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/ace-bailey?hidenav=true', 'position': 'F', 'height': {'feetAndInches': '6-8', 'inchesOnly': 80}, 'weightLbs': 203, 'school': 'Rutgers', 'status': 'Freshman', 'birthday': '08/13/2006', 'country': 'United States', 'tradeDetails': []}}
# {'pickNumber': 6, 'pickDetails': '', 'team': {'id': 1748321, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612764, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '18-64', 'seasonFinish': '5th place, Southeast Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-washington-wizards', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-washington-wizards?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Traded Walter Clayton Jr. (No. 18) to UTA', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Acquired Will Riley (No. 21) from UTA', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Traded Micah Peavy (No. 40) to NOP', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Washington Wizards', 'teamAbbr': 'WAS', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1753814, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Tre Johnson', 'firstName': 'Tre', 'lastName': 'Johnson', 'permalink': 'https://www.nba.com/draft/2025/prospects/tre-johnson', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/tre-johnson?hidenav=true', 'position': 'G', 'height': {'feetAndInches': '6-5', 'inchesOnly': 77}, 'weightLbs': 190, 'school': 'Texas', 'status': 'Freshman', 'birthday': '03/07/2006', 'country': 'United States', 'tradeDetails': []}}
# {'pickNumber': 7, 'pickDetails': '', 'team': {'id': 1748306, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612740, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '21-61', 'seasonFinish': '5th place, Southwest Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-new-orleans-pelicans', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-new-orleans-pelicans?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Acquired Derik Queen (No. 13) from ATL', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Traded Asa Newell (No. 23) to ATL', 'viewMoreWebUrl': 'https://www.nba.com/news/pelicans-hawks-derik-queen-trade-2025-draft', 'viewMoreAppUrl': 'https://www.nba.com/news/pelicans-hawks-derik-queen-trade-2025-draft', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Acquired Micah Peavy (No. 40) from WAS', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'New Orleans Pelicans', 'teamAbbr': 'NOP', 'pickedFirstRound': True}, 'prospect': {'id': 1754311, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Jeremiah Fears', 'firstName': 'Jeremiah', 'lastName': 'Fears', 'permalink': 'https://www.nba.com/draft/2025/prospects/jeremiah-fears', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/jeremiah-fears?hidenav=true', 'position': 'G', 'height': {'feetAndInches': '6-3', 'inchesOnly': 75}, 'weightLbs': 180, 'school': 'Oklahoma', 'status': 'Freshman', 'birthday': '10/14/2006', 'country': 'United States', 'tradeDetails': []}}
# {'pickNumber': 8, 'pickDetails': '', 'team': {'id': 1748274, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612751, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '26-56', 'seasonFinish': '4th place, Atlantic Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-brooklyn-nets', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-brooklyn-nets?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Acquired Drake Powell (No. 22) from ATL', 'viewMoreWebUrl': 'https://www.nba.com/news/hawks-acquire-kristaps-porzingis-3-team-trade', 'viewMoreAppUrl': 'https://www.nba.com/news/hawks-acquire-kristaps-porzingis-3-team-trade', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Adou Thiero (No. 36) traded to LAL', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Brooklyn Nets', 'teamAbbr': 'BKN', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1755102, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Egor Demin', 'firstName': 'Egor', 'lastName': 'Demin', 'permalink': 'https://www.nba.com/draft/2025/prospects/egor-demin', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/egor-demin?hidenav=true', 'position': 'G-F', 'height': {'feetAndInches': '6-8', 'inchesOnly': 80}, 'weightLbs': 199, 'school': 'BYU', 'status': 'Freshman', 'birthday': '03/03/2006', 'country': 'Russia', 'tradeDetails': []}}
# {'pickNumber': 9, 'pickDetails': '', 'team': {'id': 1748319, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612761, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '30-52', 'seasonFinish': '3rd place, Atlantic Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-toronto-raptors', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-toronto-raptors?hidenav=true', 'tradeDetails': [], 'teamName': 'Toronto Raptors', 'teamAbbr': 'TOR', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1757625, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Collin Murray-Boyles', 'firstName': 'Collin', 'lastName': 'Murray-Boyles', 'permalink': 'https://www.nba.com/draft/2025/prospects/collin-murray-boyles', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/collin-murray-boyles?hidenav=true', 'position': 'F', 'height': {'feetAndInches': '6-7', 'inchesOnly': 79}, 'weightLbs': 240, 'school': 'South Carolina', 'status': 'Sophomore', 'birthday': '06/10/2005', 'country': 'United States', 'tradeDetails': []}}
# {'pickNumber': 10, 'pickDetails': 'Traded to Phoenix', 'team': {'id': 1748287, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612745, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '52-30', 'seasonFinish': '1st place, Southwest Division', 'playoffsFinish': 'Lost in first round'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-houston-rockets', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-houston-rockets?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Traded Khaman Maluach (No. 10) to PHX', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Traded Jahmai Mashack (No. 59) to MEM', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Houston Rockets', 'teamAbbr': 'HOU', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1753808, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Khaman Maluach', 'firstName': 'Khaman', 'lastName': 'Maluach', 'permalink': 'https://www.nba.com/draft/2025/prospects/khaman-maluach', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/khaman-maluach?hidenav=true', 'position': 'C', 'height': {'feetAndInches': '7-1', 'inchesOnly': 85}, 'weightLbs': 253, 'school': 'Duke', 'status': 'Freshman', 'birthday': '09/14/2006', 'country': 'South Sudan', 'tradeDetails': [{'tradeDescription': 'Acquired by PHX in trade with HOU', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}]}}
# {'pickNumber': 11, 'pickDetails': 'Traded to Memphis', 'team': {'id': 1748316, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612757, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '36-46', 'seasonFinish': '4th place, Northwest Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-portland-trail-blazers', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-portland-trail-blazers?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Traded Cedric Coward (No. 11) to MEM', 'viewMoreWebUrl': 'https://www.nba.com/news/reports-grizzlies-acquire-rights-to-no-11-pick-cedric-coward-from-blazers', 'viewMoreAppUrl': 'https://www.nba.com/news/reports-grizzlies-acquire-rights-to-no-11-pick-cedric-coward-from-blazers', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Acquired Yang Hansen (No. 16) from MEM', 'viewMoreWebUrl': 'https://www.nba.com/news/reports-grizzlies-acquire-rights-to-no-11-pick-cedric-coward-from-blazers', 'viewMoreAppUrl': 'https://www.nba.com/news/reports-grizzlies-acquire-rights-to-no-11-pick-cedric-coward-from-blazers', 'viewMoreLabel': 'View more'}], 'teamName': 'Portland Trail Blazers', 'teamAbbr': 'POR', 'pickedFirstRound': True}, 'prospect': {'id': 1754842, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Cedric Coward', 'firstName': 'Cedric', 'lastName': 'Coward', 'permalink': 'https://www.nba.com/draft/2025/prospects/cedric-coward', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/cedric-coward?hidenav=true', 'position': 'G-F', 'height': {'feetAndInches': '6-5', 'inchesOnly': 77}, 'weightLbs': 213, 'school': 'Washington State', 'status': 'Junior', 'birthday': '09/11/2003', 'country': 'United States', 'tradeDetails': [{'tradeDescription': 'Acquired by MEM in trade with POR', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}]}}
# {'pickNumber': 12, 'pickDetails': '', 'team': {'id': 1748276, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612741, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '39-43', 'seasonFinish': '5th place, Central Division', 'playoffsFinish': 'Lost in SoFi Play-In Tournament'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-chicago-bulls', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-chicago-bulls?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Rocco Zikarsky traded (No. 45) to MIN', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Acquired Lachlan Olbrich (No. 55) from LAL', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Chicago Bulls', 'teamAbbr': 'CHI', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 
 'teamRecord': {'season': '2024-25', 'winsAndLosses': '18-64', 'seasonFinish': '5th place, Southeast Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-washington-wizards', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-washington-wizards?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Traded Walter Clayton Jr. (No. 18) to UTA', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Acquired Will Riley (No. 21) from UTA', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Traded Micah Peavy (No. 40) to NOP', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Washington Wizards', 'teamAbbr': 'WAS', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1756334, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Walter Clayton Jr.', 'firstName': 'Walter', 'lastName': 'Clayton Jr.', 'permalink': 'https://www.nba.com/draft/2025/prospects/walter-clayton-jr', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/walter-clayton-jr?hidenav=true', 'position': 'G', 'height': {'feetAndInches': '6-2', 'inchesOnly': 74}, 'weightLbs': 199, 'school': 'Florida', 'status': 'Senior', 'birthday': '03/06/2003', 'country': 'United States', 'tradeDetails': [{'tradeDescription': 'Acquired by UTA in trade with WAS', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}]}}
# {'pickNumber': 19, 'pickDetails': '', 'team': {'id': 1748274, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612751, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '26-56', 'seasonFinish': '4th place, Atlantic Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-brooklyn-nets', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-brooklyn-nets?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Acquired Drake Powell (No. 22) from ATL', 'viewMoreWebUrl': 'https://www.nba.com/news/hawks-acquire-kristaps-porzingis-3-team-trade', 'viewMoreAppUrl': 'https://www.nba.com/news/hawks-acquire-kristaps-porzingis-3-team-trade', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Adou Thiero (No. 36) traded to LAL', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Brooklyn Nets', 'teamAbbr': 'BKN', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1757579, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Nolan Traoré', 'firstName': 'Nolan', 'lastName': 'Traoré', 'permalink': 'https://www.nba.com/draft/2025/prospects/nolan-traore', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/nolan-traore?hidenav=true', 'position': 'G', 'height': {'feetAndInches': '6-5', 'inchesOnly': 77}, 'weightLbs': 175, 'school': 'Saint-Quentin BB (France)', 'status': 'International', 'birthday': '05/28/2006', 'country': 'France', 'tradeDetails': []}}
# {'pickNumber': 20, 'pickDetails': '', 'team': {'id': 1748303, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612748, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '37-45', 'seasonFinish': '3rd Place, Southeast Division', 'playoffsFinish': 'Lost in SoFi Play-In Tournament'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-miami-heat', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-miami-heat?hidenav=true', 'tradeDetails': [], 'teamName': 'Miami Heat', 'teamAbbr': 'MIA', 'pickedFirstRound': True}, 'prospect': {'id': 1755126, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Kasparas Jakučionis', 'firstName': 'Kasparas', 'lastName': 'Jakučionis', 'permalink': 'https://www.nba.com/draft/2025/prospects/kasparas-jakucionis', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/kasparas-jakucionis?hidenav=true', 'position': 'G-F', 'height': {'feetAndInches': '6-5', 'inchesOnly': 77}, 'weightLbs': 205, 'school': 'Illinois', 'status': 'Freshman', 'birthday': '05/29/2006', 'country': 'Lithuania', 'tradeDetails': []}}
# {'pickNumber': 21, 'pickDetails': 'Traded to Washington', 'team': {'id': 1748320, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612762, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '17-65', 'seasonFinish': '5th, Northwest Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-utah-jazz', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-utah-jazz?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Acquired Walter Clayton Jr. (No. 18) from WAS', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Traded Will Riley (No. 21) to WAS', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Utah Jazz', 'teamAbbr': 'UTA', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1757600, 'type': 'draft_prospect', 'season': 2025, 'displayName': '
 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}]}}
# {'pickNumber': 24, 'pickDetails': 'Traded to Sacramento', 'team': {'id': 1748313, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612760, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '68-14', 'seasonFinish': '1st Place, Northwest Division', 'playoffsFinish': '2025 NBA Champions'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-oklahoma-city-thunder', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-oklahoma-city-thunder?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Traded Nique Clifford (No. 24) to SAC', 'viewMoreWebUrl': 'https://www.nba.com/kings/news/kings-acquire-draft-rights-to-nique-clifford', 'viewMoreAppUrl': 'https://www.nba.com/kings/news/kings-acquire-draft-rights-to-nique-clifford', 'viewMoreLabel': 'View more'}], 'teamName': 'Oklahoma City Thunder', 'teamAbbr': 'OKC', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1754394, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Nique Clifford', 'firstName': 'Nique', 'lastName': 'Clifford', 'permalink': 'https://www.nba.com/draft/2025/prospects/nique-clifford', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/nique-clifford?hidenav=true', 'position': 'G-F', 'height': {'feetAndInches': '6-5', 'inchesOnly': 77}, 'weightLbs': 202, 'school': 'Colorado State', 'status': 'Senior', 'birthday': '02/09/2002', 'country': 'United States', 'tradeDetails': [{'tradeDescription': 'Acquired by SAC in trade with OKC', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}]}}
# {'pickNumber': 25, 'pickDetails': '', 'team': {'id': 1748322, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612753, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '41-41', 'seasonFinish': '1st place, Southeast Division', 'playoffsFinish': 'Lost in first round'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-orlando-magic', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-orlando-magic?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Acquired Noah Penda (No. 32) from BOS', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Traded Amari Williams (No. 46) to BOS', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Traded Max Shulga (No. 57) to BOS', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Orlando Magic', 'teamAbbr': 'ORL', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1754317, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Jase Richardson', 'firstName': 'Jase', 'lastName': 'Richardson', 'permalink': 'https://www.nba.com/draft/2025/prospects/jase-richardson', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/jase-richardson?hidenav=true', 'position': 'G', 'height': {'feetAndInches': '6-1', 'inchesOnly': 73}, 'weightLbs': 178, 'school': 'Michigan State', 'status': 'Freshman', 'birthday': '10/15/2005', 'country': 'United States', 'tradeDetails': []}}
# {'pickNumber': 26, 'pickDetails': '', 'team': {'id': 1748274, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612751, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '26-56', 'seasonFinish': '4th place, Atlantic Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-brooklyn-nets', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-brooklyn-nets?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Acquired Drake Powell (No. 22) from ATL', 'viewMoreWebUrl': 'https://www.nba.com/news/hawks-acquire-kristaps-porzingis-3-team-trade', 'viewMoreAppUrl': 'https://www.nba.com/news/hawks-acquire-kristaps-porzingis-3-team-trade', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Adou Thiero (No. 36) traded to LAL', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Brooklyn Nets', 'teamAbbr': 'BKN', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1754404, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Ben Saraf', 'firstName': 'Ben', 'lastName': 'Saraf', 'permalink': 'https://www.nba.com/draft/2025/prospects/ben-saraf', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/ben-saraf?hidenav=true', 'position': 'G', 'height': {'feetAndInches': '6-6', 'inchesOnly': 78}, 'weightLbs': 201, 'school': 'Ratiopharm Ulm (Germany)', 'status': 'International', 'birthday': '04/14/2006', 'country': 'Israel', 'tradeDetails': []}}
# {'pickNumber': 27, 'pickDetails': '', 'team': {'id': 1748274, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612751, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '26-56', 'seasonFinish': '4th place, Atlantic Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-brooklyn-nets', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-brooklyn-nets?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Acquired Drake Powell (No. 22) from ATL', 'viewMoreWebUrl': 'https://www.nba.com/news/hawks-acquire-kristaps-porzingis-3-team-trade', 'viewMoreAppUrl': 'https://www.nba.com/news/hawks-acquire-kristaps-porzingis-3-team-trade', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Adou Thiero (No. 36) traded to LAL', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Brooklyn Nets', 'teamAbbr': 'BKN', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1754497, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Danny Wolf', 'firstName': 'Danny', 'lastName': 'Wolf', 'permalink': 'https://www.nba.com/draft/2025/prospects/danny-wolf', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/danny-wolf?hidenav=true', 'position': 'F-C', 'height': {'feetAndInches': '6-11', 'inchesOnly': 83}, 'weightLbs': 252, 'school': 'Michigan', 'status': 'Junior', 'birthday': '05/05/2004', 'country': 'United States', 'tradeDetails': []}}
# {'pickNumber': 28, 'pickDetails': '', 'team': {'id': 1748273, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612738, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '61-21', 'seasonFinish': '1st place, Atlantic Division', 'playoffsFinish': 'Lost in conference semifinals'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-boston-celtics', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-boston-celtics?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Traded Noah Penda (No. 32) to ORL', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Acquired Amari Williams (No. 46) from ORL', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Acquired Max Shulga (No. 57) from ORL', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Boston Celtics', 'teamAbbr': 'BOS', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1755619, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Hugo González', 'firstName': 'Hugo', 'lastName': 'González', 'permalink': 'https://www.nba.com/draft/2025/prospects/hugo-gonzalez', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/hugo-gonzalez?hidenav=true', 'position': 'G-F', 'height': {'feetAndInches': '6-6', 'inchesOnly': 78}, 'weightLbs': 205, 'school': 'Real Madrid (Spain)', 'status': 'International', 'birthday': '02/05/2006', 'country': 'Spain', 'tradeDetails': []}}
# {'pickNumber': 29, 'pickDetails': 'Traded to Charlotte', 'team': {'id': 1748315, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612756, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '36-46', 'seasonFinish': '5th place, Pacific Division', 'playoffsFinish': 'Did not qualify for playoffs'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-phoenix-suns', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-phoenix-suns?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Acquired Khaman Maluach (No. 10) from HOU', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Traded Liam McNeeley (No. 29) to CHA', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Acquired Rasheer Fleming (No. 31) from MIN', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Acquired Koby Brea (No. 41) from GSW', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Traded Alex Toohey (No. 52) to GSW', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'Phoenix Suns', 'teamAbbr': 'PHX', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1757890, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Liam McNeeley', 'firstName': 'Liam', 'lastName': 'McNeeley', 'permalink': 'https://www.nba.com/draft/2025/prospects/liam-mcneeley', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/liam-mcneeley?hidenav=true', 'position': 'F', 'height': {'feetAndInches': '6-7', 'inchesOnly': 79}, 'weightLbs': 215, 'school': 'Connecticut', 'status': 'Freshman', 'birthday': '10/10/2005', 'country': 'United States', 'tradeDetails': [{'tradeDescription': 'Acquired by CHA in trade with PHX', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}]}}
# {'pickNumber': 30, 'pickDetails': '', 'team': {'id': 1748289, 'type': 'draft_team', 'season': 2025, 'teamId': 1610612746, 'teamRecord': {'season': '2024-25', 'winsAndLosses': '50-32', 'seasonFinish': '2nd place, Pacific Division', 'playoffsFinish': 'Lost in first round'}, 'permalink': 'https://www.nba.com/draft/2025/team-profiles/2025-la-clippers', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/team-profiles/2025-la-clippers?hidenav=true', 'tradeDetails': [{'tradeDescription': 'Acquired Kobe Sanders (No. 50) from NYK', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}, {'tradeDescription': 'Traded Mohamed Diawara (No. 51) to NYK', 'viewMoreWebUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreAppUrl': 'https://www.nba.com/news/2025-nba-draft-order', 'viewMoreLabel': 'View more'}], 'teamName': 'LA Clippers', 'teamAbbr': 'LAC', 'pickedFirstRound': True, 'pickedSecondRound': True}, 'prospect': {'id': 1772763, 'type': 'draft_prospect', 'season': 2025, 'displayName': 'Yanic Konan Niederhauser', 'firstName': 'Yanic Konan', 'lastName': 'Niederhauser', 'permalink': 'https://www.nba.com/draft/2025/prospects/yanic-konan-niederhauser', 'appUrl': 'gametime://webview?url=https://www.nba.com/webview/draft/2025/prospects/yanic-konan-niederhauser?hidenav=true', 'position': 'F', 'height': {'feetAndInches': '6-11', 'inchesOnly': 83}, 'weightLbs': 243, 'school': 'Penn State', 'status': 'Junior', 'birthday': '03/14/2003', 'country': 'Switzerland', 'tradeDetails': []}}
#    PICK_NUMBER   PLAYER_NAME FIRST_NAME  LAST_NAME POSITION HEIGHT  \
# 0            1  Cooper Flagg     Cooper      Flagg        F    6-8
# 1            2  Dylan Harper      Dylan     Harper        G    6-5
# 2            3  VJ Edgecombe         VJ  Edgecombe        G    6-4
# 3            4  Kon Knueppel        Kon   Knueppel      G-F    6-7
# 4            5    Ace Bailey        Ace     Bailey        F    6-8
#
#    HEIGHT_INCHES  WEIGHT   SCHOOL    BIRTHDAY        COUNTRY     TEAM_ID  \
# 0             80     221     Duke  12/21/2006  United States  1610612742
# 1             77     213  Rutgers  03/02/2006  United States  1610612759
# 2             76     193   Baylor  07/30/2005        Bahamas  1610612755
# 3             79     217     Duke  08/03/2005  United States  1610612766
# 4             80     203  Rutgers  08/13/2006  United States  1610612762
#
#             TEAM_NAME TEAM_ABBR  SEASON
# 0    Dallas Mavericks       DAL    2025
# 1   San Antonio Spurs       SAS    2025
# 2  Philadelphia 76ers       PHI    2025
# 3   Charlotte Hornets       CHA    2025
# 4           Utah Jazz       UTA    2025

# %%
player_game_logs.columns.to_list()
# Out:
# ['SEASON_YEAR',
#  'PLAYER_ID',
#  'PLAYER_NAME',
#  'NICKNAME',
#  'TEAM_ID',
#  'TEAM_ABBREVIATION',
#  'TEAM_NAME',
#  'GAME_ID',
#  'GAME_DATE',
#  'MATCHUP',
#  'WL',
#  'MIN',
#  'FGM',
#  'FGA',
#  'FG_PCT',
#  'FG3M',
#  'FG3A',
#  'FG3_PCT',
#  'FTM',
#  'FTA',
#  'FT_PCT',
#  'OREB',
#  'DREB',
#  'REB',
#  'AST',
#  'TOV',
#  'STL',
#  'BLK',
#  'BLKA',
#  'PF',
#  'PFD',
#  'PTS',
#  'PLUS_MINUS',
#  'NBA_FANTASY_PTS',
#  'DD2',
#  'TD3',
#  'WNBA_FANTASY_PTS',
#  'GP_RANK',
#  'W_RANK',
#  'L_RANK',
#  'W_PCT_RANK',
#  'MIN_RANK',
#  'FGM_RANK',
#  'FGA_RANK',
#  'FG_PCT_RANK',
#  'FG3M_RANK',
#  'FG3A_RANK',
#  'FG3_PCT_RANK',
#  'FTM_RANK',
#  'FTA_RANK',
#  'FT_PCT_RANK',
#  'OREB_RANK',
#  'DREB_RANK',
#  'REB_RANK',
#  'AST_RANK',
#  'TOV_RANK',
#  'STL_RANK',
#  'BLK_RANK',
#  'BLKA_RANK',
#  'PF_RANK',
#  'PFD_RANK',
#  'PTS_RANK',
#  'PLUS_MINUS_RANK',
#  'NBA_FANTASY_PTS_RANK',
#  'DD2_RANK',
#  'TD3_RANK',
#  'WNBA_FANTASY_PTS_RANK',
#  'AVAILABLE_FLAG',
#  'MIN_SEC',
#  'TEAM_COUNT',
#  'W',
#  'IS_HOME']

# %%
# Get Season Schedule Function 

def getSeasonScheduleFrame(seasons,seasonType): 

    
    def getGameDate(matchup):
        return matchup.partition(' at')[0][:10]

    def getHomeTeam(matchup):
        return matchup.partition(' at')[2]

    def getAwayTeam(matchup):
        return matchup.partition(' at')[0][10:]

    def getTeamIDFromNickname(nickname):
        return teamLookup.loc[teamLookup['nickname'] == difflib.get_close_matches(nickname,teamLookup['nickname'],1)[0]].values[0][0] 
    
    @retry
    def getRegularSeasonSchedule(season,teamID,seasonType):
        season = str(season) + "-" + str(season+1)[-2:]
        teamGames = cumestatsteamgames.CumeStatsTeamGames(league_id = '00',season = season ,
                                                                      season_type_all_star=seasonType,
                                                                      team_id = teamID).get_normalized_json()

        teamGames = pd.DataFrame(json.loads(teamGames)['CumeStatsTeamGames'])
        teamGames['SEASON'] = season
        return teamGames    
    
    teamLookup = pd.DataFrame(teams.get_teams())
    
    scheduleFrames = [None] *  len(teamLookup['id'])

    for season in seasons:
        for i, id in enumerate(teamLookup['id']):
            time.sleep(1)
            scheduleFrames[i] = getRegularSeasonSchedule(season,id,seasonType)
    
    scheduleFrame = pd.concat(scheduleFrames)
    
    scheduleFrame['GAME_DATE'] = pd.to_datetime(scheduleFrame['MATCHUP'].map(getGameDate))
    scheduleFrame['HOME_TEAM_NICKNAME'] = scheduleFrame['MATCHUP'].map(getHomeTeam)
    scheduleFrame['HOME_TEAM_ID'] = scheduleFrame['HOME_TEAM_NICKNAME'].map(getTeamIDFromNickname)
    scheduleFrame['AWAY_TEAM_NICKNAME'] = scheduleFrame['MATCHUP'].map(getAwayTeam)
    scheduleFrame['AWAY_TEAM_ID'] = scheduleFrame['AWAY_TEAM_NICKNAME'].map(getTeamIDFromNickname)
    scheduleFrame = scheduleFrame.drop_duplicates() # There's a row for both teams, only need 1
    scheduleFrame = scheduleFrame.reset_index(drop=True)
            
    return scheduleFrame

# %%
# Get Single Game aggregation columns

def getSingleGameMetrics(gameID,homeTeamID,awayTeamID,awayTeamNickname,seasonYear,gameDate):

    @retry
    def getGameStats(teamID,gameID,seasonYear):
        #season = str(seasonYear) + "-" + str(seasonYear+1)[-2:]
        gameStats = cumestatsteam.CumeStatsTeam(game_ids=gameID,league_id ="00",
                                               season=seasonYear,season_type_all_star="Regular Season",
                                               team_id = teamID).get_normalized_json()

        gameStats = pd.DataFrame(json.loads(gameStats)['TotalTeamStats'])

        return gameStats

    data = getGameStats(homeTeamID,gameID,seasonYear)
    data.at[1,'NICKNAME'] = awayTeamNickname
    data.at[1,'TEAM_ID'] = awayTeamID
    data.at[1,'OFFENSIVE_EFFICIENCY'] = (data.at[1,'FG'] + data.at[1,'AST'])/(data.at[1,'FGA'] - data.at[1,'OFF_REB'] + data.at[1,'AST'] + data.at[1,'TOTAL_TURNOVERS'])
    data.at[1,'SCORING_MARGIN'] = data.at[1,'PTS'] - data.at[0,'PTS']

    data.at[0,'OFFENSIVE_EFFICIENCY'] = (data.at[0,'FG'] + data.at[0,'AST'])/(data.at[0,'FGA'] - data.at[0,'OFF_REB'] + data.at[0,'AST'] + data.at[0,'TOTAL_TURNOVERS'])
    data.at[0,'SCORING_MARGIN'] = data.at[0,'PTS'] - data.at[1,'PTS']

    data['SEASON'] = seasonYear
    data['GAME_DATE'] = gameDate
    data['GAME_ID'] = gameID

    return data

# %%
def getGameLogs(gameLogs,scheduleFrame):
    
    # Functions to prepare additional columns after gameLogs table loads
    def getHomeAwayFlag(gameDF):
        gameDF['HOME_FLAG'] = np.where((gameDF['W_HOME']==1) | (gameDF['L_HOME']==1),1,0)
        gameDF['AWAY_FLAG'] = np.where((gameDF['W_ROAD']==1) | (gameDF['L_ROAD']==1),1,0)
        #return gameDF 

    def getTotalWinPctg(gameDF):
        gameDF['TOTAL_GAMES_PLAYED'] = gameDF.groupby(['TEAM_ID','SEASON'])['GAME_DATE'].rank(ascending=True)
        gameDF['TOTAL_WINS'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['W'].cumsum()
        gameDF['TOTAL_WIN_PCTG'] = gameDF['TOTAL_WINS']/gameDF['TOTAL_GAMES_PLAYED']
        return gameDF.drop(['TOTAL_GAMES_PLAYED','TOTAL_WINS'],axis=1)

    def getHomeWinPctg(gameDF):
        gameDF['HOME_GAMES_PLAYED'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['HOME_FLAG'].cumsum()
        gameDF['HOME_WINS'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['W_HOME'].cumsum()
        gameDF['HOME_WIN_PCTG'] = gameDF['HOME_WINS']/gameDF['HOME_GAMES_PLAYED']
        return gameDF.drop(['HOME_GAMES_PLAYED','HOME_WINS'],axis=1)

    def getAwayWinPctg(gameDF):
        gameDF['AWAY_GAMES_PLAYED'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['AWAY_FLAG'].cumsum()
        gameDF['AWAY_WINS'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['W_ROAD'].cumsum()
        gameDF['AWAY_WIN_PCTG'] = gameDF['AWAY_WINS']/gameDF['AWAY_GAMES_PLAYED']
        return gameDF.drop(['AWAY_GAMES_PLAYED','AWAY_WINS'],axis=1)

    def getRollingOE(gameDF):
        gameDF['ROLLING_OE'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['OFFENSIVE_EFFICIENCY'].transform(lambda x: x.rolling(3, 1).mean())

    def getRollingScoringMargin(gameDF):
        gameDF['ROLLING_SCORING_MARGIN'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['SCORING_MARGIN'].transform(lambda x: x.rolling(3, 1).mean())

    def getRestDays(gameDF):
        gameDF['LAST_GAME_DATE'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['GAME_DATE'].shift(1)
        gameDF['NUM_REST_DAYS'] = (gameDF['GAME_DATE'] - gameDF['LAST_GAME_DATE'])/np.timedelta64(1,'D') 
        return gameDF.drop('LAST_GAME_DATE',axis=1)
    
    start = time.perf_counter_ns()

    i = int(len(gameLogs)/2) #Can use a previously completed gameLog datasetn

    gameLogs_lst = [None] * len(scheduleFrame)

    while i<len(scheduleFrame):
        time.sleep(1)
         
        try:
            gameLogs_lst[i] = getSingleGameMetrics(
                scheduleFrame.at[i,'GAME_ID'],
                scheduleFrame.at[i,'HOME_TEAM_ID'],
                scheduleFrame.at[i,'AWAY_TEAM_ID'],
                scheduleFrame.at[i,'AWAY_TEAM_NICKNAME'],
                scheduleFrame.at[i,'SEASON'],
                scheduleFrame.at[i,'GAME_DATE']
            )
        except Exception as e:
            print(f"Error at i={i}: {e}")
            break
    
        # gameLogs =  pd.concat([gameLogs,getSingleGameMetrics(scheduleFrame.at[i,'GAME_ID'],scheduleFrame.at[i,'HOME_TEAM_ID'],
        #                  scheduleFrame.at[i,'AWAY_TEAM_ID'],scheduleFrame.at[i,'AWAY_TEAM_NICKNAME'],
        #                  scheduleFrame.at[i,'SEASON'],scheduleFrame.at[i,'GAME_DATE'])])
        
        # gameLogs = gameLogs.reset_index(drop=True)

        end = time.perf_counter_ns()

        if i%5==0:
            print(f"Processing game {i} of {len(scheduleFrame)}")
        if i%100 == 0:
            mins = ((end-start)/1e9)/60
            print(i,mins)
            if i != 0:
                pd.concat([df for df in gameLogs_lst if isinstance(df, pd.DataFrame)]).to_pickle(f'gameLogs_checkpoint_{i}.pkl')

        i+=1
    

    gameLogs = pd.concat([df for df in gameLogs_lst if isinstance(df, pd.DataFrame)])
    gameLogs = gameLogs.reset_index(drop=True)

    # Get Table Level Aggregation Columns
    getHomeAwayFlag(gameLogs)
    gameLogs = getHomeWinPctg(gameLogs)
    gameLogs = getAwayWinPctg(gameLogs)
    gameLogs = getTotalWinPctg(gameLogs)
    getRollingScoringMargin(gameLogs)
    getRollingOE(gameLogs)
    gameLogs = getRestDays(gameLogs)

    return gameLogs.reset_index(drop=True)

# %%
#Get ScheduleFrame

seasons = [2020] #,2021,2022]
seasonType = 'Regular Season'

start = time.perf_counter_ns()
scheduleFrame = getSeasonScheduleFrame(seasons,seasonType)
end = time.perf_counter_ns()

secs = (end-start)/1e9
mins = secs/60
print(mins)
# Out:
# 1.54762989445

# %%
# Get a batch of game IDs from your scheduleFrame
game_id_batch = scheduleFrame['GAME_ID'].iloc[0:10].tolist()

# # Try comma-separated
# game_ids_str = ','.join(game_id_batch)

# Or try pipe-separated  
game_ids_str = '|'.join(game_id_batch)

# Test the call
result = cumestatsteam.CumeStatsTeam(
    game_ids=game_ids_str,
    team_id=scheduleFrame.at[0, 'HOME_TEAM_ID'],
    season='2023-24',
    season_type_all_star='Regular Season'
)

# print(pd.DataFrame(json.loads(result)['TotalTeamStats']))
print(json.loads(result.get_normalized_json())['TotalTeamStats'])


# gameStats = cumestatsteam.CumeStatsTeam(game_ids=gameID,league_id ="00",
#                                                season=seasonYear,season_type_all_star="Regular Season",
#                                                team_id = teamID).get_normalized_json()

#         gameStats = pd.DataFrame(json.loads(gameStats)['TotalTeamStats'])
# Out:
# [{'CITY': 'Atlanta', 'NICKNAME': 'Hawks', 'TEAM_ID': 1610612737, 'W': 7, 'L': 3, 'W_HOME': 7, 'L_HOME': 0, 'W_ROAD': 0, 'L_ROAD': 3, 'TEAM_TURNOVERS': 4, 'TEAM_REBOUNDS': 63, 'GP': 10, 'GS': 50, 'ACTUAL_MINUTES': 2400, 'ACTUAL_SECONDS': 0, 'FG': 425, 'FGA': 865, 'FG_PCT': 0.491, 'FG3': 119, 'FG3A': 307, 'FG3_PCT': 0.388, 'FT': 195, 'FTA': 241, 'FT_PCT': 0.809, 'OFF_REB': 102, 'DEF_REB': 375, 'TOT_REB': 540, 'AST': 245, 'PF': 188, 'STL': 66, 'TOTAL_TURNOVERS': 128, 'BLK': 54, 'PTS': 1164, 'AVG_REB': 54.0, 'AVG_PTS': 116.4, 'DQ': 0}, {'CITY': 'OPPONENTS', 'NICKNAME': ' ', 'TEAM_ID': 0, 'W': 3, 'L': 7, 'W_HOME': 3, 'L_HOME': 0, 'W_ROAD': 0, 'L_ROAD': 7, 'TEAM_TURNOVERS': 4, 'TEAM_REBOUNDS': 64, 'GP': 10, 'GS': 50, 'ACTUAL_MINUTES': 2400, 'ACTUAL_SECONDS': 0, 'FG': 428, 'FGA': 923, 'FG_PCT': 0.464, 'FG3': 121, 'FG3A': 335, 'FG3_PCT': 0.361, 'FT': 151, 'FTA': 192, 'FT_PCT': 0.786, 'OFF_REB': 103, 'DEF_REB': 315, 'TOT_REB': 482, 'AST': 263, 'PF': 190, 'STL': 87, 'TOTAL_TURNOVERS': 109, 'BLK': 47, 'PTS': 1128, 'AVG_REB': 48.2, 'AVG_PTS': 112.8, 'DQ': 0}]

# %%
#Example Output of Single Game Metrics
getSingleGameMetrics(scheduleFrame.at[104,'GAME_ID'],scheduleFrame.at[104,'HOME_TEAM_ID'],
                     scheduleFrame.at[104,'AWAY_TEAM_ID'],scheduleFrame.at[104,'AWAY_TEAM_NICKNAME'],
                     scheduleFrame.at[104,'SEASON'],scheduleFrame.at[104,'GAME_DATE'])
# Out:
#         CITY   NICKNAME     TEAM_ID  W  L  W_HOME  L_HOME  W_ROAD  L_ROAD  \
# 0  Cleveland  Cavaliers  1610612739  1  0       1       0       0       0
# 1  OPPONENTS    Celtics  1610612738  0  1       0       0       0       1
#
#    TEAM_TURNOVERS  ...  BLK  PTS  AVG_REB  AVG_PTS  DQ  OFFENSIVE_EFFICIENCY  \
# 0               2  ...    3  117     49.0    117.0   0              0.588785
# 1               0  ...    9  110     48.0    110.0   0              0.567308
#
#    SCORING_MARGIN   SEASON  GAME_DATE     GAME_ID
# 0             7.0  2020-21 2021-03-17  0022000620
# 1            -7.0  2020-21 2021-03-17  0022000620
#
# [2 rows x 41 columns]

# %%
#Create the gameLogs DataFrame
gameLogs = pd.DataFrame()
gameLogs = getGameLogs(gameLogs,scheduleFrame)
# gameLogs.to_csv('gameLogs.csv')
# Out:
# Processing game 0 of 1080
# 0 0.01909224375
# Processing game 5 of 1080
# Processing game 10 of 1080
# Processing game 15 of 1080
# Processing game 20 of 1080
# Processing game 25 of 1080
# Processing game 30 of 1080
# Processing game 35 of 1080
# Processing game 40 of 1080
# Processing game 45 of 1080
# Processing game 50 of 1080
# Processing game 55 of 1080
# Processing game 60 of 1080
# Processing game 65 of 1080
# Processing game 70 of 1080
# Processing game 75 of 1080
# Processing game 80 of 1080
# Processing game 85 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 90 of 1080
# Processing game 95 of 1080
# Processing game 100 of 1080
# 100 7.865775867366667
# Processing game 105 of 1080
# Processing game 110 of 1080
# Processing game 115 of 1080
# Processing game 120 of 1080
# Processing game 125 of 1080
# Processing game 130 of 1080
# Processing game 135 of 1080
# Processing game 140 of 1080
# Processing game 145 of 1080
# Processing game 150 of 1080
# Processing game 155 of 1080
# Processing game 160 of 1080
# Processing game 165 of 1080
# Processing game 170 of 1080
# Processing game 175 of 1080
# Processing game 180 of 1080
# Processing game 185 of 1080
# Processing game 190 of 1080
# Processing game 195 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 200 of 1080
# 200 22.718097383333333
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 205 of 1080
# Processing game 210 of 1080
# Processing game 215 of 1080
# Processing game 220 of 1080
# Processing game 225 of 1080
# Processing game 230 of 1080
# Processing game 235 of 1080
# Processing game 240 of 1080
# Processing game 245 of 1080
# Processing game 250 of 1080
# Processing game 255 of 1080
# Processing game 260 of 1080
# Processing game 265 of 1080
# Processing game 270 of 1080
# Processing game 275 of 1080
# Attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing game 280 of 1080
# Attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 285 of 1080
# Processing game 290 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 295 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 300 of 1080
# 300 41.64058276666666
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 305 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 310 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 315 of 1080
# Processing game 320 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 325 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 330 of 1080
# Processing game 335 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 340 of 1080
# Processing game 345 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 350 of 1080
# Processing game 355 of 1080
# Attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 360 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 365 of 1080
# Processing game 370 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 375 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 380 of 1080
# Processing game 385 of 1080
# Processing game 390 of 1080
# Processing game 395 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 400 of 1080
# 400 65.92527933541666
# Processing game 405 of 1080
# Processing game 410 of 1080
# Processing game 415 of 1080
# Processing game 420 of 1080
# Processing game 425 of 1080
# Processing game 430 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Processing game 435 of 1080
# Processing game 440 of 1080
# Processing game 445 of 1080
# Processing game 450 of 1080
# Processing game 455 of 1080
# Processing game 460 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Attempt 2 failed: Expecting value: line 1 column 1 (char 0)
# Processing game 465 of 1080
# Processing game 470 of 1080
# Processing game 475 of 1080
# Attempt 1 failed: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# Attempt 2 failed: Expecting value: line 1 column 1 (char 0)
# Attempt 3 failed: Expecting value: line 1 column 1 (char 0)
# Error at i=478: Failed after 3 attempts

# %%
#Example Output of Game Logs
gameLogs[(gameLogs['TEAM_ID'] == 1610612737 ) & (gameLogs['SEASON'] == '2022-23')].sort_values('GAME_DATE')
# Out:
#            CITY NICKNAME     TEAM_ID  W  L  W_HOME  L_HOME  W_ROAD  L_ROAD  \
# 4696    Atlanta    Hawks  1610612737  1  0       1       0       0       0
# 4694    Atlanta    Hawks  1610612737  1  0       1       0       0       0
# 4692    Atlanta    Hawks  1610612737  0  1       0       1       0       0
# 4691  OPPONENTS    Hawks  1610612737  1  0       0       0       1       0
# 4689  OPPONENTS    Hawks  1610612737  1  0       0       0       1       0
# 4687  OPPONENTS    Hawks  1610612737  0  1       0       0       0       1
# 4685  OPPONENTS    Hawks  1610612737  0  1       0       0       0       1
# 4683  OPPONENTS    Hawks  1610612737  1  0       0       0       1       0
# 4680    Atlanta    Hawks  1610612737  1  0       1       0       0       0
# 4678    Atlanta    Hawks  1610612737  1  0       1       0       0       0
# 4676    Atlanta    Hawks  1610612737  0  1       0       1       0       0
# 4674    Atlanta    Hawks  1610612737  1  0       1       0       0       0
# 4673  OPPONENTS    Hawks  1610612737  0  1       0       0       0       1
# 4671  OPPONENTS    Hawks  1610612737  1  0       0       0       1       0
# 4668    Atlanta    Hawks  1610612737  0  1       0       1       0       0
# 4666    Atlanta    Hawks  1610612737  1  0       1       0       0       0
# 4665  OPPONENTS    Hawks  1610612737  0  1       0       0       0       1
# 4662    Atlanta    Hawks  1610612737  1  0       1       0       0       0
# 4661  OPPONENTS    Hawks  1610612737  0  1       0       0       0       1
# 4658    Atlanta    Hawks  1610612737  0  1       0       1       0       0
# 4657  OPPONENTS    Hawks  1610612737  0  1       0       0       0       1
# 4655  OPPONENTS    Hawks  1610612737  1  0       0       0       1       0
# 4652    Atlanta    Hawks  1610612737  1  0       1       0       0       0
# 4650    Atlanta    Hawks  1610612737  0  1       0       1       0       0
# 4649  OPPONENTS    Hawks  1610612737  0  1       0       0       0       1
# 4647  OPPONENTS    Hawks  1610612737  0  1       0       0       0       1
# 4644    Atlanta    Hawks  1610612737  1  0       1       0       0       0
# 4643  OPPONENTS    Hawks  1610612737  0  1       0       0       0       1
# 4641  OPPONENTS    Hawks  1610612737  0  1       0       0       0       1
# 4639  OPPONENTS    Hawks  1610612737  1  0       0       0       1       0
# 4636    Atlanta    Hawks  1610612737  1  0       1       0       0       0
sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['OFFENSIVE_EFFICIENCY'].shift(1)
        gameDF['LAST_GAME_HOME_WIN_PCTG'] = gameDF.sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['HOME_WIN_PCTG'].shift(1)
        gameDF['LAST_GAME_AWAY_WIN_PCTG'] = gameDF.sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['AWAY_WIN_PCTG'].shift(1)
        gameDF['LAST_GAME_TOTAL_WIN_PCTG'] = gameDF.sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['TOTAL_WIN_PCTG'].shift(1)
        gameDF['LAST_GAME_ROLLING_SCORING_MARGIN'] = gameDF.sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['ROLLING_SCORING_MARGIN'].shift(1)
        gameDF['LAST_GAME_ROLLING_OE'] = gameDF.sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['ROLLING_OE'].shift(1)
    
    
    def getHomeTeamFrame(gameDF):
        homeTeamFrame = gameDF[gameDF['CITY'] != 'OPPONENTS']
        homeTeamFrame = homeTeamFrame[['LAST_GAME_OE','LAST_GAME_HOME_WIN_PCTG','NUM_REST_DAYS','LAST_GAME_AWAY_WIN_PCTG','LAST_GAME_TOTAL_WIN_PCTG','LAST_GAME_ROLLING_SCORING_MARGIN','LAST_GAME_ROLLING_OE','W','TEAM_ID','GAME_ID','SEASON']]

        colRenameDict = {}
        for col in homeTeamFrame.columns:
            if (col != 'GAME_ID') & (col != 'SEASON') :
                colRenameDict[col] = 'HOME_' + col 

        homeTeamFrame.rename(columns=colRenameDict,inplace=True)

        return homeTeamFrame

    def getAwayTeamFrame(gameDF):
        awayTeamFrame = gameDF[gameDF['CITY'] == 'OPPONENTS']
        awayTeamFrame = awayTeamFrame[['LAST_GAME_OE','LAST_GAME_HOME_WIN_PCTG','NUM_REST_DAYS','LAST_GAME_AWAY_WIN_PCTG','LAST_GAME_TOTAL_WIN_PCTG','LAST_GAME_ROLLING_SCORING_MARGIN','LAST_GAME_ROLLING_OE','TEAM_ID','GAME_ID','SEASON']]

        colRenameDict = {}
        for col in awayTeamFrame.columns:
            if (col != 'GAME_ID') & (col != 'SEASON'):
                colRenameDict[col] = 'AWAY_' + col 

        awayTeamFrame.rename(columns=colRenameDict,inplace=True)

        return awayTeamFrame
    
    shiftGameLogRecords(gameLogs)
    awayTeamFrame = getAwayTeamFrame(gameLogs)
    homeTeamFrame = getHomeTeamFrame(gameLogs)
    
    return pd.merge(homeTeamFrame, awayTeamFrame, how="inner", on=[ "GAME_ID","SEASON"]).drop(['GAME_ID','AWAY_TEAM_ID','HOME_TEAM_ID'],axis=1)

# %%
modelData = getGameLogFeatureSet(gameLogs)

# %%
# Final Data Set before Train,Test, Validation Split
modelData
# Out:
#       HOME_LAST_GAME_OE  HOME_LAST_GAME_HOME_WIN_PCTG  HOME_NUM_REST_DAYS  \
# 0              0.555556                      0.685714                 3.0
# 1              0.573913                      0.676471                 1.0
# 2              0.584746                      0.666667                 2.0
# 3              0.609756                      0.656250                 4.0
# 4              0.512397                      0.354839                 1.0
# ...                 ...                           ...                 ...
# 2900           0.578512                      0.333333                 4.0
# 2901           0.540146                      0.600000                 2.0
# 2902           0.490909                      0.250000                 2.0
# 2903           0.531250                      1.000000                 2.0
# 2904           0.513043                      0.307692                 3.0
#
#       HOME_LAST_GAME_AWAY_WIN_PCTG  HOME_LAST_GAME_TOTAL_WIN_PCTG  \
# 0                         0.444444                       0.563380
# 1                         0.444444                       0.557143
# 2                         0.444444                       0.550725
# 3                         0.444444                       0.544118
# 4                         0.558824                       0.461538
# ...                            ...                            ...
# 2900                      0.250000                       0.285714
# 2901                      0.500000                       0.562500
# 2902                      0.333333                       0.300000
# 2903                      0.500000                       0.666667
# 2904                      0.214286                       0.259259
#
#       HOME_LAST_GAME_ROLLING_SCORING_MARGIN  HOME_LAST_GAME_ROLLING_OE  \
# 0                                  9.333333                   0.571405
# 1                                 -0.666667                   0.589472
# 2                                  8.666667                   0.640592
# 3                                 11.333333                   0.653327
# 4                                 11.000000                   0.596498
# ...                                     ...                        ...
# 2900                              -9.000000                   0.565270
# 2901                               3.333333                   0.556248
# 2902                             -17.666667                   0.488297
# 2903                              -0.333333                   0.547383
# 2904                             -14.333333                   0.556458
#
#       HOME_W   SEASON  AWAY_LAST_GAME_OE  AWAY_LAST_GAME_HOME_WIN_PCTG  \
# 0          1  2020-21           0.612903                      0.250000
# 1          1  2020-21           0.500000                      0.305556
# 2          1  2020-21           0.612403                      0.500000
# 3          1  2020-21           0.539568                      0.500000
# 4          1  2020-21           0.727273                      0.656250
# ...      ...      ...                ...                           ...
# 2900       1  2022-23           0.537037                      0.666667
# 2901       1  2022-23           0.511278                      0.142857
# 2902       0  2022-23           0.568966                      0.400000
# 2903       1  2022-23           0.533898                      1.000000
# 2904       0  2022-23           0.577236                      0.307692
#
#       AWAY_NUM_REST_DAYS  AWAY_LAST_GAME_AWAY_WIN_PCTG  \
# 0                    2.0                      0.228571
# 1                    2.0                      0.303030
# 2                    2.0                      0.428571
# 3                    2.0                      0.441176
# 4                    1.0                      0.457143
# ...                  ...                           ...
# 2900                 2.0                      0.300000
# 2901                 2.0                      0.300000
# 2902                 1.0                      0.400000
# 2903                 3.0                      0.000000
# 2904                 3.0                      0.187500
#
#       AWAY_LAST_GAME_TOTAL_WIN_PCTG  AWAY_LAST_GAME_ROLLING_SCORING_MARGIN  \
# 0                          0.239437                              -2.000000
# 1                          0.304348                             -18.000000
# 2                          0.463768                               0.666667
# 3                          0.470588                               0.666667
# 4                          0.552239                              17.333333
# ...                             ...                                    ...
# 2900                       0.500000                               0.000000
# 2901                       0.235294                              -5.000000
# 2902                       0.400000                             -12.666667
# 2903                       0.333333                              -9.666667
# 2904                       0.241379                              -8.000000
#
#       AWAY_LAST_GAME_ROLLING_OE
# 0                      0.605315
# 1                      0.512228
# 2                      0.567718
# 3                      0.570866
# 4                      0.633081
# ...                         ...
# 2900                   0.622617
# 2901                   0.555121
# 2902                   0.565603
# 2903                   0.549413
# 2904                   0.512440
#
# [2905 rows x 16 columns]

# %%
modelData.to_csv('nbaHomeWinLossModelDataset.csv')
